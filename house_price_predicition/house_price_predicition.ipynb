# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (1.24.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: altair<6,>=4.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (5.0.1)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (4.2.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (8.0.4)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: numpy<2,>=1 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (1.25.2)
# Requirement already satisfied: packaging<24,>=14.1 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (23.1)
# Requirement already satisfied: pandas<3,>=0.25 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<10,>=6.2.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<5,>=3.20 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=4.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: pympler<2,>=0.9 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (0.9)
# Requirement already satisfied: python-dateutil<3,>=2 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (2.8.2)
# Requirement already satisfied: requests<3,>=2.4 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.11.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (13.3.5)
# Requirement already satisfied: tenacity<9,>=8.0.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (8.2.2)
# Requirement already satisfied: toml<2 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.0.1 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (4.7.1)
# Requirement already satisfied: tzlocal<5,>=1.1 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (2.1)
# Requirement already satisfied: validators<1,>=0.2 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (0.18.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (3.1.30)
# Requirement already satisfied: pydeck<1,>=0.1.dev5 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (0.7.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (6.3.2)
# Requirement already satisfied: watchdog in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from streamlit) (2.1.6)
# Requirement already satisfied: jinja2 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from altair<6,>=4.0->streamlit) (4.17.3)
# Requirement already satisfied: toolz in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from altair<6,>=4.0->streamlit) (0.12.0)
# Requirement already satisfied: colorama in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from gitpython!=3.1.19,<4,>=3->streamlit) (4.0.7)
# Requirement already satisfied: zipp>=0.5 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from importlib-metadata<7,>=1.4->streamlit) (3.11.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from pandas<3,>=0.25->streamlit) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from pandas<3,>=0.25->streamlit) (2023.3)
# Requirement already satisfied: ipywidgets>=7.0.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from pydeck<1,>=0.1.dev5->streamlit) (8.0.4)
# Requirement already satisfied: traitlets>=4.3.2 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from pydeck<1,>=0.1.dev5->streamlit) (5.7.1)
# Requirement already satisfied: ipykernel>=5.1.2 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from pydeck<1,>=0.1.dev5->streamlit) (6.25.0)
# Requirement already satisfied: six>=1.5 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from python-dateutil<3,>=2->streamlit) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from requests<3,>=2.4->streamlit) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from requests<3,>=2.4->streamlit) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from requests<3,>=2.4->streamlit) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from requests<3,>=2.4->streamlit) (2023.7.22)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from rich<14,>=10.11.0->streamlit) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from rich<14,>=10.11.0->streamlit) (2.15.1)
# Requirement already satisfied: decorator>=3.4.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from validators<1,>=0.2->streamlit) (5.1.1)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3->streamlit) (4.0.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.1.2)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (8.12.2)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (5.3.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.1.6)
# Requirement already satisfied: nest-asyncio in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (1.5.6)
# Requirement already satisfied: psutil in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (5.9.0)
# Requirement already satisfied: pyzmq>=20 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (23.2.0)
# Requirement already satisfied: widgetsnbextension~=4.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipywidgets>=7.0.0->pydeck<1,>=0.1.dev5->streamlit) (4.0.5)
# Requirement already satisfied: jupyterlab-widgets~=3.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipywidgets>=7.0.0->pydeck<1,>=0.1.dev5->streamlit) (3.0.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14,>=10.11.0->streamlit) (0.1.0)
# Requirement already satisfied: backcall in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (3.0.36)
# Requirement already satisfied: stack-data in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.2.0)
# Requirement already satisfied: entrypoints in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (305.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.2.5)
# Requirement already satisfied: executing in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\swapnil.joshi\.conda\envs\swapnil\lib\site-packages (from stack-data->ipython>=7.23.1->ipykernel>=5.1.2->pydeck<1,>=0.1.dev5->streamlit) (0.2.2)

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('Housing.csv')

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# 1                no             yes        3       no        furnished
# 2                no              no        2      yes   semi-furnished
# 3                no             yes        3      yes        furnished
# 4                no             yes        2       no        furnished
# ..              ...             ...      ...      ...              ...
# 540              no              no        2       no      unfurnished
# 541              no              no        0       no   semi-furnished
# 542              no              no        0       no      unfurnished
# 543              no              no        0       no        furnished
# 544              no              no        0       no      unfurnished
#
# [545 rows x 13 columns]

# %%
df['area'].max()
# Out:
# 16200

# %%
df['stories'].max()
# Out:
# 4

# %%
df['furnishingstatus'].value_counts()
# Out:
# semi-furnished    227
# unfurnished       178
# furnished         140
# Name: furnishingstatus, dtype: int64

# %%
df.shape
# Out:
# (545, 13)

# %%
df.describe().T
# Out:
#            count          mean           std        min        25%        50%  \
# price      545.0  4.766729e+06  1.870440e+06  1750000.0  3430000.0  4340000.0
# area       545.0  5.150541e+03  2.170141e+03     1650.0     3600.0     4600.0
# bedrooms   545.0  2.965138e+00  7.380639e-01        1.0        2.0        3.0
# bathrooms  545.0  1.286239e+00  5.024696e-01        1.0        1.0        1.0
# stories    545.0  1.805505e+00  8.674925e-01        1.0        1.0        2.0
# parking    545.0  6.935780e-01  8.615858e-01        0.0        0.0        0.0
#
#                  75%         max
# price      5740000.0  13300000.0
# area          6360.0     16200.0
# bedrooms         3.0         6.0
# bathrooms        2.0         4.0
# stories          2.0         4.0
# parking          1.0         3.0

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus'],
#       dtype='object')

# %%
df['mainroad'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df['guestroom'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['furnishingstatus'].unique()
# Out:
# array(['furnished', 'semi-furnished', 'unfurnished'], dtype=object)

# %%
df.nunique()
# Out:
# price               219
# area                284
# bedrooms              6
# bathrooms             4
# stories               4
# mainroad              2
# guestroom             2
# basement              2
# hotwaterheating       2
# airconditioning       2
# parking               4
# prefarea              2
# furnishingstatus      3
# dtype: int64

# %%
df.isna().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
df.corr()
# Out:
#               price      area  bedrooms  bathrooms   stories   parking
# price      1.000000  0.535997  0.366494   0.517545  0.420712  0.384394
# area       0.535997  1.000000  0.151858   0.193820  0.083996  0.352980
# bedrooms   0.366494  0.151858  1.000000   0.373930  0.408564  0.139270
# bathrooms  0.517545  0.193820  0.373930   1.000000  0.326165  0.177496
# stories    0.420712  0.083996  0.408564   0.326165  1.000000  0.045547
# parking    0.384394  0.352980  0.139270   0.177496  0.045547  1.000000

# %%
label_encoder = LabelEncoder()

columns_to_encode = ['mainroad', 'guestroom', 'basement', 'hotwaterheating','prefarea','airconditioning','furnishingstatus']

for column in columns_to_encode:
    df[column] = label_encoder.fit_transform(df[column])

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0           0                0                1        2         1
# 1           0                0                1        3         0
# 2           1                0                0        2         1
# 3           1                0                1        3         1
# 4           1                0                1        2         0
# ..        ...              ...              ...      ...       ...
# 540         1                0                0        2         0
# 541         0                0                0        0         0
# 542         0                0                0        0         0
# 543         0                0                0        0         0
# 544         0                0                0        0         0
#
#      furnishingstatus
# 0                   0
# 1                   0
# 2                   1
# 3                   0
# 4                   0
# ..                ...
# 540                 2
# 541                 1
# 542                 2
# 543                 0
# 544                 2
#
# [545 rows x 13 columns]

# %%
#df = pd.get_dummies(df, columns=['furnishingstatus'], prefix=['furnishingstatus'])

# %%
#df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0           0                0                1        2         1
# 1           0                0                1        3         0
# 2           1                0                0        2         1
# 3           1                0                1        3         1
# 4           1                0                1        2         0
# ..        ...              ...              ...      ...       ...
# 540         1                0                0        2         0
# 541         0                0                0        0         0
# 542         0                0                0        0         0
# 543         0                0                0        0         0
# 544         0                0                0        0         0
#
#      furnishingstatus_furnished  furnishingstatus_semi-furnished  \
# 0                             1                                0
# 1                             1                                0
# 2                             0                                1
# 3                             1                                0
# 4                             1                                0
# ..                          ...                              ...
# 540                           0                                0
# 541                           0                                1
# 542                           0                                0
# 543                           1                                0
# 544                           0                                0
#
#      furnishingstatus_unfurnished
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ..                            ...
# 540                             1
# 541                             0
# 542                             1
# 543                             0
# 544                             1
#
# [545 rows x 15 columns]

# %%
df.corr()
# Out:
#                                     price      area  bedrooms  bathrooms  \
# price                            1.000000  0.535997  0.366494   0.517545
# area                             0.535997  1.000000  0.151858   0.193820
# bedrooms                         0.366494  0.151858  1.000000   0.373930
# bathrooms                        0.517545  0.193820  0.373930   1.000000
# stories                          0.420712  0.083996  0.408564   0.326165
# mainroad                         0.296898  0.288874 -0.012033   0.042398
# guestroom                        0.255517  0.140297  0.080549   0.126469
# basement                         0.187057  0.047417  0.097312   0.102106
# hotwaterheating                  0.093073 -0.009229  0.046049   0.067159
# airconditioning                  0.452954  0.222393  0.160603   0.186915
# parking                          0.384394  0.352980  0.139270   0.177496
# prefarea                         0.329777  0.234779  0.079023   0.063472
# furnishingstatus_furnished       0.229350  0.145772  0.079054   0.108139
# furnishingstatus_semi-furnished  0.063656  0.006156  0.050040   0.029834
# furnishingstatus_unfurnished    -0.280587 -0.142278 -0.126252  -0.132107
#
#                                   stories  mainroad  guestroom  basement  \
# price                            0.420712  0.296898   0.255517  0.187057
# area                             0.083996  0.288874   0.140297  0.047417
# bedrooms                         0.408564 -0.012033   0.080549  0.097312
# bathrooms                        0.326165  0.042398   0.126469  0.102106
# stories                          1.000000  0.121706   0.043538 -0.172394
# mainroad                         0.121706  1.000000   0.092337  0.044002
# guestroom                        0.043538  0.092337   1.000000  0.372066
# basement                        -0.172394  0.044002   0.372066  1.000000
# hotwaterheating                  0.018847 -0.011781  -0.010308  0.004385
# airconditioning                  0.293602  0.105423   0.138179  0.047341
# parking                          0.045547  0.204433   0.037466  0.051497
# prefarea                         0.044425  0.199876   0.160897  0.228083
# furnishingstatus_furnished       0.093176  0.129971   0.099721  0.069852
# furnishingstatus_semi-furnished -0.003648  0.011450   0.005821  0.050284
# furnishingstatus_unfurnished    -0.082972 -0.133123  -0.099023 -0.117935
#
#                                  hotwaterheating  airconditioning   parking  \
# price                                   0.093073         0.452954  0.384394
# area                                   -0.009229         0.222393  0.352980
# bedrooms                                0.046049         0.160603  0.139270
# bathrooms                               0.067159         0.186915  0.177496
# stories                                 0.018847         0.293602  0.045547
# mainroad                               -0.011781         0.105423  0.204433
# guestroom                              -0.010308         0.138179  0.037466
# basement                                0.004385         0.047341  0.051497
# hotwaterheating                         1.000000        -0.130023  0.067864
# airconditioning                        -0.130023         1.000000  0.159173
# parking                                 0.067864         0.159173  1.000000
# prefarea                               -0.059411         0.117382  0.091627
# furnishingstatus_furnished             -0.008472         0.160994  0.131234
# furnishingstatus_semi-furnished         0.063819        -0.053179  0.041327
# furnishingstatus_unfurnished           -0.059194        -0.094086 -0.165705
#
#                                  prefarea  furnishingstatus_furnished  \
# price                            0.329777                    0.229350
# area                             0.234779                    0.145772
# bedrooms                         0.079023                    0.079054
# bathrooms                        0.063472                    0.108139
# stories                          0.044425                    0.093176
# mainroad                         0.199876                    0.129971
# guestroom                        0.160897                    0.099721
# basement                         0.228083                    0.069852
# hotwaterheating                 -0.059411                   -0.008472
# airconditioning                  0.117382                    0.160994
# parking                          0.091627                    0.131234
# prefarea                         1.000000                    0.100249
# furnishingstatus_furnished       0.100249                    1.000000
# furnishingstatus_semi-furnished -0.011535                   -0.496748
# furnishingstatus_unfurnished    -0.081271                   -0.409462
#
#                                  furnishingstatus_semi-furnished  \
# price                                                   0.063656
# area                                                    0.006156
# bedrooms                                                0.050040
# bathrooms                                               0.029834
# stories                                                -0.003648
# mainroad                                                0.011450
# guestroom                                               0.005821
# basement                                                0.050284
# hotwaterheating                                         0.063819
# airconditioning                                        -0.053179
# parking                                                 0.041327
# prefarea                                               -0.011535
# furnishingstatus_furnished                             -0.496748
# furnishingstatus_semi-furnished                         1.000000
# furnishingstatus_unfurnished                           -0.588405
#
#                                  furnishingstatus_unfurnished
# price                                               -0.280587
# area                                                -0.142278
# bedrooms                                            -0.126252
# bathrooms                                           -0.132107
# stories                                             -0.082972
# mainroad                                            -0.133123
# guestroom                                           -0.099023
# basement                                            -0.117935
# hotwaterheating                                     -0.059194
# airconditioning                                     -0.094086
# parking                                             -0.165705
# prefarea                                            -0.081271
# furnishingstatus_furnished                          -0.409462
# furnishingstatus_semi-furnished                     -0.588405
# furnishingstatus_unfurnished                         1.000000

# %%
plt.figure(figsize=(18, 12))
sns.heatmap(df.corr(), annot = True,cmap='Spectral', fmt=".2f", linewidths=1)
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.pairplot(df)

# %%
df.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'prefarea', 'furnishingstatus_furnished',
#        'furnishingstatus_semi-furnished', 'furnishingstatus_unfurnished'],
#       dtype='object')

# %%
sns.boxplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price'>

# %%
sns.boxplot(df['area'])
# Out:
# <AxesSubplot:xlabel='area'>

# %%
x = df.drop('price',axis=1)
y = df['price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2)

# %%
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R-squared: {r2:.2f}")
# Out:
# MAE: 754928.95
# MSE: 1106232694973.33
# RMSE: 1051775.97
# R-squared: 0.69

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.6886903448603916

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values")
plt.show()

# %%
from sklearn.model_selection import cross_val_score

scores = cross_val_score(model, x, y, cv=5)  # 5-fold cross-validation
scores
# Out:
# array([ -1.94277003,  -5.00707214, -16.22431367, -21.10749485,
#         -5.27173317])

# %%
from sklearn.tree import DecisionTreeRegressor
model_dt = DecisionTreeRegressor()
model_dt.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model_dt.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R-squared: {r2:.2f}")
# Out:
# MAE: 1017376.15
# MSE: 2128557302752.29
# RMSE: 1458957.61
# R-squared: 0.40

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values")
plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
model_rf = RandomForestRegressor()
model_rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model_dt.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R-squared: {r2:.2f}")
# Out:
# MAE: 1017376.15
# MSE: 2128557302752.29
# RMSE: 1458957.61
# R-squared: 0.40

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values")
plt.show()

# %%
from xgboost import XGBRegressor
model_xgb = XGBRegressor(n_estimators=150, max_depth=5, learning_rate=0.1, random_state=20)
model_xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.1, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=5, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=150, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=20, ...)

# %%
y_pred=model_xgb.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

print(f"MAE: {mae:.2f}")
print(f"MSE: {mse:.2f}")
print(f"RMSE: {rmse:.2f}")
print(f"R-squared: {r2:.2f}")
# Out:
# MAE: 817681.95
# MSE: 1359208747482.54
# RMSE: 1165851.08
# R-squared: 0.62

# %%
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Actual vs. Predicted Values")
plt.show()

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    13300000  7420         4          2        3         1          0
# 1    12250000  8960         4          4        4         1          0
# 2    12250000  9960         3          2        2         1          0
# 3    12215000  7500         4          2        2         1          0
# 4    11410000  7420         4          1        2         1          1
# ..        ...   ...       ...        ...      ...       ...        ...
# 540   1820000  3000         2          1        1         1          0
# 541   1767150  2400         3          1        1         0          0
# 542   1750000  3620         2          1        1         1          0
# 543   1750000  2910         3          1        1         0          0
# 544   1750000  3850         3          1        2         1          0
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0           0                0                1        2         1
# 1           0                0                1        3         0
# 2           1                0                0        2         1
# 3           1                0                1        3         1
# 4           1                0                1        2         0
# ..        ...              ...              ...      ...       ...
# 540         1                0                0        2         0
# 541         0                0                0        0         0
# 542         0                0                0        0         0
# 543         0                0                0        0         0
# 544         0                0                0        0         0
#
#      furnishingstatus_furnished  furnishingstatus_semi-furnished  \
# 0                             1                                0
# 1                             1                                0
# 2                             0                                1
# 3                             1                                0
# 4                             1                                0
# ..                          ...                              ...
# 540                           0                                0
# 541                           0                                1
# 542                           0                                0
# 543                           1                                0
# 544                           0                                0
#
#      furnishingstatus_unfurnished
# 0                               0
# 1                               0
# 2                               0
# 3                               0
# 4                               0
# ..                            ...
# 540                             1
# 541                             0
# 542                             1
# 543                             0
# 544                             1
#
# [545 rows x 15 columns]

# %%
import pickle

# %%
# Serialize (save) the model to a file
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file, protocol=3)

# %%
streamlit run app.py
# Out:
#   File "C:\Users\SWAPNI~1.JOS\AppData\Local\Temp/ipykernel_22996/3737097518.py", line 1
#     streamlit run app.py
#               ^
# SyntaxError: invalid syntax
